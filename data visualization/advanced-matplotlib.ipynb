# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
iris=pd.read_csv("iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris["Species"]=iris["Species"].replace({"Iris-setosa":1,"Iris-virginica":2,"Iris-versicolor":3})
plt.scatter(iris["SepalLengthCm"],iris["PetalLengthCm"],c=iris["Species"],cmap="viridis",alpha=0.7)
plt.colorbar()

# %%
batter=pd.read_csv("batter.csv")
plt.figure(figsize=(15,6))
plt.scatter(batter["avg"],batter["strike_rate"])
for i in range(0,25):
    plt.text(batter["avg"].values[i],batter["strike_rate"].values[i],batter["batter"].values[i],fontdict={"color":"red"})
plt.axhline(130,color="red")
plt.axhline(140)
plt.axvline(40)

# %%
fig,ax=plt.subplots(nrows=2,ncols=1,sharex=True)
ax[0].scatter(batter["avg"],batter["strike_rate"],color="red")
ax[0].set_title("avg vs strike rate")
ax[0].set_ylabel("strike rate")
ax[1].scatter(batter["avg"],batter["runs"])
ax[1].set_title("avg vs runs")
ax[1].set_xlabel("avg")
ax[1].set_ylabel("runs")
# Out:
# Text(0, 0.5, 'runs')

# %%
fig,ax=plt.subplots(nrows=2,ncols=2,figsize=(15,10))
ax[0,0].scatter(batter["avg"],batter["strike_rate"])
ax[0,1].scatter(batter["avg"],batter["runs"])
ax[1,0].hist(batter["avg"])
ax[1,1].hist(batter["runs"])
# Out:
# (array([499.,  40.,  19.,  19.,   9.,   6.,   4.,   4.,   3.,   2.]),
#  array([   0. ,  663.4, 1326.8, 1990.2, 2653.6, 3317. , 3980.4, 4643.8,
#         5307.2, 5970.6, 6634. ]),
#  <BarContainer object of 10 artists>)

# %%
fig=plt.figure()
ax1=fig.add_subplot(2,2,1)
ax1.scatter(batter["avg"],batter["strike_rate"])
ax2=fig.add_subplot(2,2,2)
ax2.scatter(batter["avg"],batter["runs"])

# %%
fig=plt.figure()
ax=plt.subplot(projection="3d")
ax.scatter3D(batter["avg"],batter["strike_rate"],batter["runs"])
ax.set_title("IPL Batsman analysis")
# Out:
# Text(0.5, 0.92, 'IPL Batsman analysis')

# %%
x=[10,20,30,40]
y=[0,20,30,40]
z=[0,20,30,50]
ax1=plt.subplot(projection="3d")
ax1.scatter(x,y,z,marker="+",s=[100,100,100,100],alpha=0.7)
ax1.plot3D(x,y,z,color="red")

# %%
x=np.linspace(10,-10,100)
y=np.linspace(10,-10,100)
xx,yy=np.meshgrid(x,y)
zz=np.sin(xx)+np.cos(yy)
ax2=plt.subplot(projection="3d")
p=ax2.plot_surface(xx,yy,zz,cmap="viridis")
fig.colorbar(p)
# Out:
# C:\Users\Shreya Sharma\AppData\Local\Temp\ipykernel_21048\3725487114.py:7: UserWarning: Adding colorbar to a different Figure <Figure size 640x480 with 2 Axes> than <Figure size 640x480 with 1 Axes> which fig.colorbar is called on.
#   fig.colorbar(p)

# %%
ax3=plt.subplot()
ax3.contour(xx,yy,zz)
ax3.contourf(xx,yy,zz)

# %%
ipl=pd.read_csv("IPL_Ball_by_Ball_2008_2022 (1).csv")
ipl=ipl[(ipl["ballnumber"].isin([1,2,3,4,5,6])) & (ipl["batsman_run"]==6)]
ipl2=ipl.pivot_table(index="overs",columns="ballnumber",values="batsman_run",aggfunc="count")
plt.imshow(ipl2)
plt.yticks(sorted(ipl["overs"].unique()),list(range(1,21)))
plt.xticks(np.arange(0,6),list(range(1,7)))
plt.colorbar()

# %%
tips=sns.load_dataset("tips")
tips["size"]=tips["size"]*100
tips.plot(kind="scatter",x="total_bill",y="tip",marker="+",s=tips["size"],c=tips["sex"],cmap="viridis")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:4618, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4617 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4618     colors = mcolors.to_rgba_array(c)
#    4619 except (TypeError, ValueError) as err:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\colors.py:512, in to_rgba_array(c, alpha)
#     511 else:
# --> 512     rgba = np.array([to_rgba(cc) for cc in c])
#     514 if alpha is not None:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\colors.py:314, in to_rgba(c, alpha)
#     313 if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 314     rgba = _to_rgba_no_colorcycle(c, alpha)
#     315     try:
#
# ...

# %%
stocks=pd.read_csv("https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/weekly_stocks.csv")
stocks[["MSFT","FB","Date"]].plot(kind="line",x="Date")
stocks.plot(kind="line",subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >], dtype=object)

# %%
# batsman=pd.read_csv("batsman_season_record.csv")
# batsman.plot(kind="bar")
# batsman.plot(kind="bar",stacked=True)
tips.groupby("sex")["total_bill"].mean().plot(kind="bar")
stocks[["MSFT","FB"]].plot(kind="hist",bins=40)
# Out:
# C:\Users\Shreya Sharma\AppData\Local\Temp\ipykernel_21048\860662548.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby("sex")["total_bill"].mean().plot(kind="bar")
# <Axes: ylabel='Frequency'>
