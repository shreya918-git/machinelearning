# %%
import numpy as np
import pandas as pd
import seaborn as sns 
from sklearn.tree import DecisionTreeClassifier
import scipy.stats as stats
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer
df=pd.read_csv("tested.csv",usecols=["Age","Fare","Survived"])
df["Age"].fillna(df["Age"].mean(),inplace=True)
df["Fare"].fillna(df["Fare"].mean(),inplace=True)
X=df.iloc[:,1:3]
Y=df.iloc[:,0]
[X_train,X_test,Y_train,Y_test]=train_test_split(X,Y)
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.distplot(X_train["Age"])
plt.title("Age pdf")
plt.subplot(122)
stats.probplot(X_train["Age"],dist="norm",plot=plt)
plt.title("QQ plot")
plt.show()
# Out:
# C:\Users\Shreya Sharma\AppData\Local\Temp\ipykernel_14676\4174467500.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].mean(),inplace=True)
# C:\Users\Shreya Sharma\AppData\Local\Temp\ipykernel_14676\4174467500.py:15: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.distplot(X_train["Fare"])
plt.title("Fare pdf")
plt.subplot(122)
stats.probplot(X_train["Fare"],dist="norm",plot=plt)
plt.title("QQ plot")
plt.show()
# Out:
# C:\Users\Shreya Sharma\AppData\Local\Temp\ipykernel_14676\915730072.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train["Fare"])

# %%
clf=LogisticRegression()
clf.fit(X_train,Y_train)
Y_pred1=clf.predict(X_test)
tree=DecisionTreeClassifier()
tree.fit(X_train,Y_train)
Y_pred2=tree.predict(X_test)
print(accuracy_score(Y_pred1,Y_test))
print(accuracy_score(Y_pred2,Y_test))
tnf1=FunctionTransformer(func=lambda x:x**2)
X_train_new=tnf1.fit_transform(X_train)
X_test_new=tnf1.transform(X_test)
clf.fit(X_train_new,Y_train)
Y_pred_new=clf.predict(X_test_new)
accuracy_score(Y_pred_new,Y_test)
tree.fit(X_train_new,Y_train)
Y_pred_new2=tree.predict(X_test_new)
accuracy_score(Y_pred_new,Y_test)
accuracy_score(Y_pred_new2,Y_test)
cross_val_score(tree,X_train_new,Y_train,cv=5,scoring="accuracy").mean()
#if we had to apply function transformer to only one column we use column transformer
tnf2=ColumnTransformer([("tnf2",FunctionTransformer(func=np.log1p),["Fare"])],remainder="passthrough")
X_train_new2=tnf2.fit_transform(X_train)
X_test_new2=tnf2.transform(X_test)
clf.fit(X_train_new2,Y_train)
Y_pred_new3=clf.predict(X_test_new2)
tree.fit(X_train_new2,Y_train)
Y_pred_new4=tree.predict(X_test_new2)
accuracy_score(Y_pred_new3,Y_test)
accuracy_score(Y_pred_new4,Y_test)
# Out:
# 0.6285714285714286
# 0.6
# 0.638095238095238

# %%
plt.figure(figsize=(14,4))
plt.subplot(121)
sns.distplot(X_train_new["Age"])
stats.probplot(X_train_new["Age"],dist="norm",plot=plt)
plt.title("Age after function transformer")
plt.subplot(122)
sns.distplot(X_train_new["Fare"])
stats.probplot(X_train_new["Fare"],dist="norm",plot=plt)
plt.title("Fare after function transformer")
plt.show()
# Out:
# C:\Users\Shreya Sharma\AppData\Local\Temp\ipykernel_14676\2400490556.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train_new["Age"])
# C:\Users\Shreya Sharma\AppData\Local\Temp\ipykernel_14676\2400490556.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
for col in X_train.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(X_train[col])
    plt.title(col)
    plt.subplot(122)
    stats.probplot(X_train[col],dist="norm",plot=plt)
    plt.title(col)
    plt.show()
# Out:
# C:\Users\Shreya Sharma\AppData\Local\Temp\ipykernel_14676\3032713228.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train[col])
# C:\Users\Shreya Sharma\AppData\Local\Temp\ipykernel_14676\3032713228.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...
