# %% [markdown]
# <b><h2>Csv,tsv,json,sql file formats.</h2></b>
# <h3>Csv file format,most commonly used comma seperated values.</h3>
# <h3>Tsv file format,tab seperated values.</h3>

# %%
import pandas as pd
pd.read_csv("placement-dataset.csv") #direct fetching with read_csv
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
import requests   #extracting csv files from the net
from io import StringIO
url="https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers={"User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14;rv:66.0) Gecko 20100101 Firefox/66.0"}
data=requests.get(url,headers)
text_data=StringIO(data.text)
pd.read_csv(text_data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %%
import pandas as pd  #to read tsv files you need to mention seperating operator 
pd.read_csv('mtcars.tsv',sep='/t')
# Out:
# C:\Users\Shreya Sharma\AppData\Local\Temp\ipykernel_14896\2423249966.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   pd.read_csv('mtcars.tsv',sep='/t')
#    model\tmpg\tcyl\tdisp\thp\tdrat\twt\tqsec\tvs\tam\tgear\tcarb
# 0   Mazda RX4\t21\t6\t160\t110\t3.9\t2.62\t16.46\t...
# 1   Mazda RX4 Wag\t21\t6\t160\t110\t3.9\t2.875\t17...
# 2   Datsun 710\t22.8\t4\t108\t93\t3.85\t2.32\t18.6...
# 3   Hornet 4 Drive\t21.4\t6\t258\t110\t3.08\t3.215...
# 4   Hornet Sportabout\t18.7\t8\t360\t175\t3.15\t3....
# 5   Valiant\t18.1\t6\t225\t105\t2.76\t3.46\t20.22\...
# 6   Duster 360\t14.3\t8\t360\t245\t3.21\t3.57\t15....
# 7   Merc 240D\t24.4\t4\t146.7\t62\t3.69\t3.19\t20\...
# 8   Merc 230\t22.8\t4\t140.8\t95\t3.92\t3.15\t22.9...
# 9   Merc 280\t19.2\t6\t167.6\t123\t3.92\t3.44\t18....
# ...
