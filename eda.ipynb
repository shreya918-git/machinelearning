# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("tested.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
# sns.countplot(df['Embarked'])  #bar graph for categorical data
df["Embarked"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Embarked'>

# %%
df["Embarked"].value_counts().plot(kind="pie",autopct='%.2f') #pie chart for categorical data
# Out:
# <Axes: ylabel='count'>

# %%
plt.hist(df["Age"],bins=4) #distributes the numerical data into bins or ranges
# Out:
# (array([ 61., 182.,  73.,  16.]),
#  array([ 0.17  , 19.1275, 38.085 , 57.0425, 76.    ]),
#  <BarContainer object of 4 artists>)

# %%
sns.distplot(df["Age"]) #tells about the pdf and skewness of the numerical column
# Out:
# C:\Users\Shreya Sharma\AppData\Local\Temp\ipykernel_31488\2732350774.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.boxplot(df["Age"]) #tells about the outliers,median,minimum and maximum
# Out:
# <Axes: ylabel='Age'>

# %%
df["Age"].mean()
# Out:
# 30.272590361445783

# %%
df["Age"].min()
# Out:
# 0.17

# %%
df["Age"].max()
# Out:
# 76.0

# %%
df["Age"].mode()
# Out:
# 0    21.0
# 1    24.0
# Name: Age, dtype: float64

# %%
tips=sns.load_dataset("tips")
iris=sns.load_dataset("iris")
flight=sns.load_dataset("flights")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# <b><h2>Numerical-Numerical</h2></b>

# %%
import seaborn as sns
sns.scatterplot(x='total_bill', y='tip', data=tips,hue="sex",style="smoker",size="size") #we use hue,style and size to analyse 5 columns together that is tips.total bill,sex,smoker and size
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# <b><h2>Numerical-Categorical</h2></b>

# %%
sns.barplot(x="Pclass",y="Age",data=df,hue="Sex") #gives the distribution of average value of the numerical column
                                                  #the black rode tells about the confidence interval
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.boxplot(x="Sex",y="Age",data=df,hue="Survived")
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
sns.distplot(df[df["Survived"]==1]["Age"],hist=False)
sns.distplot(df[df["Survived"]==0]["Age"],hist=False)
# Out:
# C:\Users\Shreya Sharma\AppData\Local\Temp\ipykernel_31488\1572643976.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df["Survived"]==1]["Age"],hist=False)
# C:\Users\Shreya Sharma\AppData\Local\Temp\ipykernel_31488\1572643976.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
sns.heatmap(pd.crosstab(df["Survived"],df["Pclass"]))
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
sns.clustermap(pd.crosstab(df["Survived"],df["Pclass"]))

# %%
sns.pairplot(df)

# %%
sns.lineplot(x="total_bill",y="tip",data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
